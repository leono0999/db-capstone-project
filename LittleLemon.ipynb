# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "meta_user", password = "1234")

# %%
connection = connector.connect(user = "meta_user", password = "1234", db = "littlelemondm")

# %%
cursor=connection.cursor()

# %%
show_tables_query='show tables'

# %%
cursor.execute(show_tables_query)

# %%
results=cursor.fetchall()

# %%
for result in results:
    print(result)
# Out:
# ('bookings',)
# ('customer',)
# ('joinview',)
# ('menuitems',)
# ('menuitemsview',)
# ('menus',)
# ('orderdeliverystatus',)
# ('orders',)
# ('ordersview',)
# ('staffinformation',)

# %%
print(results)
# Out:
# [('bookings',), ('customer',), ('joinview',), ('menuitems',), ('menuitemsview',), ('menus',), ('orderdeliverystatus',), ('orders',), ('ordersview',), ('staffinformation',)]

# %%
customertable='select * from customer'
cursor.execute(customertable)
results=cursor.fetchall()
for result in results:
    print(result)
# Out:
# (1, 'Juan Perez', '234243', 'juan@hotmail.com')
# (2, 'Maria Gracia', '2342743', 'maria@hotmail.com')
# (3, 'Isac Guerrero', '6342743', 'isacc@hotmail.com')
# (4, 'Carlos Garcia', '9342743', 'carlos@hotmail.com')

# %%
join_fullname='select c.FullName, c.ContactNumber from customer c inner join orders o on c.CustomerID=o.CustomerID where o.Cost > 60.0'

# %%
cursor.execute(join_fullname)

# %%
results=cursor.fetchall()
for result in results:
    print(result)
